# %% [markdown]
# <a href="https://colab.research.google.com/github/Pmilivojevic/PyTorch/blob/main/Seq2Seq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m spacy download de_core_news_sm
# !pip install -U torchtext==0.6
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.datasets import Multi30k
from torchtext.data import Field, TabularDataset, BucketIterator, Iterator
import numpy as np
import spacy
import random
from torch.utils.tensorboard import SummaryWriter
import pandas as pd
from sklearn.model_selection import train_test_split

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
english_txt = open(
    '/content/drive/MyDrive/ColabNotebooks/PyTorch/Datasets/europarl-v7.de-en.en',
    encoding='utf8'
).read().split('\n')

german_txt = open(
    '/content/drive/MyDrive/ColabNotebooks/PyTorch/Datasets/europarl-v7.de-en.de',
    encoding='utf8'
).read().split('\n')

raw_data = {
    'English': [line for line in english_txt],
    'German': [line for line in german_txt]
}

df = pd.DataFrame(raw_data, columns=['English', 'German'])

train, test = train_test_split(df, test_size=0.2)

train.to_json(
    '/content/drive/MyDrive/ColabNotebooks/PyTorch/Datasets/train_de.json',
    orient='records',
    lines=True
)
test.to_json(
    '/content/drive/MyDrive/ColabNotebooks/PyTorch/Datasets/test_de.json',
    orient='records',
    lines=True
)

# %%
spacy_eng = spacy.load('en_core_web_sm')
spacy_ger = spacy.load('de_core_news_sm')

def tokenize_eng(text):
  return [tok.text for tok in spacy_eng.tokenizer(text)]

def tokenize_ger(text):
  return [tok.text for tok in spacy_ger.tokenizer(text)]

english = Field(
    tokenize=tokenize_eng,
    lower=True,
    init_token='<sos>',
    eos_token='<eos>'
)

german = Field(
    tokenize=tokenize_ger,
    lower=True,
    init_token='<sos>',
    eos_token='<eos>'
)

fields = {'English': ('eng', english), 'German': ('ger', german)}

train_data, test_data = TabularDataset.splits(
    path='/content/drive/MyDrive/ColabNotebooks/PyTorch/Datasets',
    train='train_de.json',
    test='test_de.json',
    format='json',
    fields=fields
)

english.build_vocab(train_data, max_size=10000, min_freq=2)
german.build_vocab(train_data, max_size=10000, min_freq=2)

# %%
class Encoder(nn.Module):
  def __init__(
      self,
      input_size,
      embedding_size,
      hidden_size,
      num_layers,
      drop
  ):
    super().__init__()

    self.hidden_size = hidden_size
    self.num_layers = num_layers

    self.dropout = nn.Dropout(drop)
    self.embedding = nn.Embedding(input_size, embedding_size)
    self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, dropout=drop)

  def forward(self, x):
    embedding = self.dropout(self.embedding(x))
    output, (hidd, cell) = self.rnn(embedding)

    return hidd, cell

# %%
class Decoder(nn.Module):
  def __init__(
      self,
      input_size,
      embedding_size,
      hidden_size,
      output_size,
      num_layers,
      drop
  ):
    super().__init__()

    self.hidden_size = hidden_size
    self.num_layers = num_layers

    self.dropout = nn.Dropout(drop)
    self.embedding = nn.Embedding(input_size, embedding_size)
    self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, dropout=drop)
    self.fc = nn.Linear(hidden_size, output_size)

  def forward(self, x, hidd, cell):
    x = x.unsqueeze(0)
    embedding = self.dropout(self.embedding(x))
    outputs, (hidd, cell) = self.rnn(embedding, hidd, cell)
    preds = self.fc(outputs)
    preds = preds.squeeze(0)

    return preds, hidd, cell

# %%
class Seq2Seq(nn.Module):
  def __init__(self, encoder, decoder):
    super().__init__()

    self.encoder = encoder
    self.decoder = decoder

  def forward(self, source, target, teacher_force_ratio=0.5):
    batch_size = source.shape[1]
    target_len = target.shape[0]
    target_vocab_size = len(english.vocab)

    outs = torch.zeros(target_len, batch_size, target_vocab_size).to(device)

    hidd, cell = self.encoder(source)

    x = target[0]

    for t in range(1, target_len):
      out, hidd, cell = self.decoder(x, hidd, cell)

      outs[t] = out

      best_guess = out.argmax(1)

      x = target[t] if random.random() < teacher_force_ratio else best_guess

    return outs

# %%
num_epochs = 20
lr = 0.001
batch_size = 64

load_model = False
input_size_encoder = len(german.vocab)
input_size_decoder = len(english.vocab)
output_size = len(english.vocab)
enc_emb_size = 300
dec_emb_size = 300
hidden_size = 1024
num_layers = 2
enc_drop = 0.5
dec_drop = 0.5

writer = SummaryWriter(f'runs/loss_plot')
step = 0

train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size=batch_size,
    # sort_within_batch=True,
    # sort_key=lambda x: len(x.source),
    device=device
)

encoder = Encoder(
    input_size_encoder,
    enc_emb_size,
    hidden_size,
    num_layers,
    enc_drop
).to(device)

decoder = Decoder(
    input_size_decoder,
    dec_emb_size,
    hidden_size,
    output_size,
    num_layers,
    dec_drop
).to(device)

model = Seq2Seq(encoder, decoder).to(device)

pad_idx = english.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
for epoch in range(num_epochs):
  print(f'Epoch [{epoch} / {num_epochs}]')

  for batch_idx, batch in enumerate(train_iterator):
    input = batch.ger.to(device)
    target = batch.eng.to(device)

    out = model(input, target)

    out = out[1:].reshape(-1, out.shape[2])
    target = target[1:].reshape(-1)

    optimizer.zero_grad()

    loss = criterion(out, target)

    loss.backward()
    torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=1)
    optimizer.step()

    writer.add_scalar('Training loss', loss, global_step=step)
    step+= 1
# Out:
# Epoch [0 / 20]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-8757bfbc2ec0> in <cell line: 1>()
#       6     target = batch.eng.to(device)
#       7
# ----> 8     out = model(input, target)
#       9
#      10     out = out[1:].reshape(-1, out.shape[2])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-9-2b4f122c3b40> in forward(self, source, target, teacher_force_ratio)
#      18
#      19     for t in range(1, target_len):
# ---> 20       out, hidd, cell = self.decoder(x, hidd, cell)
#      21
#      22       outs[t] = out
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-8-c40883ff0a5c> in forward(self, x, hidd, cell)
#      22     x = x.unsqueeze(0)
#      23     embedding = self.dropout(self.embedding(x))
# ---> 24     outputs, (hidd, cell) = self.rnn(embedding, hidd, cell)
#      25     preds = self.fc(outputs)
#      26     preds = preds.squeeze(0)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# TypeError: LSTM.forward() takes from 2 to 3 positional arguments but 4 were given

# %%
for epoch in range(num_epochs):
  print(f'Epoch [{epoch} / {num_epochs}]')

  for batch_idx, batch in enumerate(train_iterator):
    print(batch_idx)
    print(batch.eng.shape)
# Out:
# Epoch [0 / 20]
# 0
# torch.Size([83, 64])
# 1
# torch.Size([102, 64])
# 2
# torch.Size([75, 64])
# 3
# torch.Size([77, 64])
# 4
# torch.Size([79, 64])
# 5
# torch.Size([65, 64])
# 6
# torch.Size([121, 64])
# 7
# torch.Size([115, 64])
# 8
# torch.Size([62, 64])
# 9
# torch.Size([76, 64])
# 10
# torch.Size([77, 64])
# 11
# torch.Size([123, 64])
# 12
# torch.Size([69, 64])
# 13
# torch.Size([86, 64])
# 14
# torch.Size([100, 64])
# 15
# torch.Size([118, 64])
# 16
# torch.Size([78, 64])
# 17
# torch.Size([91, 64])
# 18
# torch.Size([76, 64])
# 19
# torch.Size([81, 64])
# 20
# torch.Size([67, 64])
# 21
# torch.Size([89, 64])
# 22
# torch.Size([70, 64])
# 23
# torch.Size([98, 64])
# 24
# torch.Size([82, 64])
# 25
# torch.Size([75, 64])
# 26
# torch.Size([70, 64])
# 27
# torch.Size([73, 64])
# 28
# torch.Size([99, 64])
# 29
# torch.Size([94, 64])
# 30
# torch.Size([70, 64])
# 31
# torch.Size([81, 64])
# 32
# torch.Size([88, 64])
# 33
# torch.Size([90, 64])
# 34
# torch.Size([78, 64])
# 35
# torch.Size([79, 64])
# 36
# torch.Size([81, 64])
# 37
# torch.Size([137, 64])
# 38
# torch.Size([83, 64])
# 39
# torch.Size([99, 64])
# 40
# torch.Size([103, 64])
# 41
# torch.Size([108, 64])
# 42
# torch.Size([67, 64])
# 43
# torch.Size([116, 64])
# 44
# torch.Size([71, 64])
# 45
# torch.Size([97, 64])
# 46
# torch.Size([125, 64])
# 47
# torch.Size([83, 64])
# 48
# torch.Size([90, 64])
# 49
# torch.Size([72, 64])
# 50
# torch.Size([91, 64])
# 51
# torch.Size([93, 64])
# 52
# torch.Size([74, 64])
# 53
# torch.Size([104, 64])
# 54
# torch.Size([108, 64])
# 55
# torch.Size([80, 64])
# 56
# torch.Size([78, 64])
# 57
# torch.Size([109, 64])
# 58
# torch.Size([71, 64])
# 59
# torch.Size([62, 64])
# 60
# torch.Size([112, 64])
# 61
# torch.Size([88, 64])
# 62
# torch.Size([164, 64])
# 63
# torch.Size([77, 64])
# 64
# torch.Size([76, 64])
# 65
# torch.Size([69, 64])
# 66
# torch.Size([71, 64])
# 67
# torch.Size([83, 64])
# 68
# torch.Size([85, 64])
# 69
# torch.Size([99, 64])
# 70
# torch.Size([82, 64])
# 71
# torch.Size([90, 64])
# 72
# torch.Size([87, 64])
# 73
# torch.Size([91, 64])
# 74
# torch.Size([74, 64])
# 75
# torch.Size([79, 64])
# 76
# torch.Size([91, 64])
# 77
# torch.Size([85, 64])
# 78
# torch.Size([67, 64])
# 79
# torch.Size([84, 64])
# 80
# torch.Size([93, 64])
# 81
# torch.Size([88, 64])
# 82
# torch.Size([67, 64])
# 83
# torch.Size([87, 64])
# 84
# torch.Size([86, 64])
# 85
# torch.Size([53, 64])
# 86
# torch.Size([83, 64])
# 87
# torch.Size([98, 64])
# 88
# torch.Size([78, 64])
# 89
# torch.Size([96, 64])
# 90
# torch.Size([102, 64])
# 91
# torch.Size([104, 64])
# 92
# torch.Size([87, 64])
# 93
# torch.Size([63, 64])
# 94
# torch.Size([80, 64])
# 95
# torch.Size([81, 64])
# 96
# torch.Size([78, 64])
# 97
# torch.Size([89, 64])
# 98
# torch.Size([75, 64])
# 99
# torch.Size([130, 64])
# 100
# torch.Size([79, 64])
# 101
# torch.Size([59, 64])
# 102
# torch.Size([101, 64])
# 103
# torch.Size([79, 64])
# 104
# torch.Size([65, 64])
# 105
# torch.Size([89, 64])
# 106
# torch.Size([75, 64])
# 107
# torch.Size([94, 64])
# 108
# torch.Size([78, 64])
# 109
# torch.Size([72, 64])
# 110
# torch.Size([133, 64])
# 111
# torch.Size([84, 64])
# 112
# torch.Size([95, 64])
# 113
# torch.Size([81, 64])
# 114
# torch.Size([72, 64])
# 115
# torch.Size([95, 64])
# 116
# torch.Size([80, 64])
# 117
# torch.Size([82, 64])
# 118
# torch.Size([71, 64])
# 119
# torch.Size([84, 64])
# 120
# torch.Size([77, 64])
# 121
# torch.Size([84, 64])
# 122
# torch.Size([72, 64])
# 123
# torch.Size([126, 64])
# 124
# torch.Size([71, 64])
# 125
# torch.Size([95, 64])
# 126
# torch.Size([86, 64])
# 127
# torch.Size([75, 64])
# 128
# torch.Size([94, 64])
# 129
# torch.Size([80, 64])
# 130
# torch.Size([113, 64])
# 131
# torch.Size([98, 64])
# 132
# torch.Size([111, 64])
# 133
# torch.Size([66, 64])
# 134
# torch.Size([91, 64])
# 135
# torch.Size([94, 64])
# 136
# torch.Size([80, 64])
# 137
# torch.Size([76, 64])
# 138
# torch.Size([111, 64])
# 139
# torch.Size([101, 64])
# 140
# torch.Size([136, 64])
# 141
# torch.Size([63, 64])
# 142
# torch.Size([63, 64])
# 143
# torch.Size([70, 64])
# 144
# torch.Size([76, 64])
# 145
# torch.Size([65, 64])
# 146
# torch.Size([79, 64])
# 147
# torch.Size([74, 64])
# 148
# torch.Size([78, 64])
# 149
# torch.Size([109, 64])
# 150
# torch.Size([74, 64])
# 151
# torch.Size([70, 64])
# 152
# torch.Size([111, 64])
# 153
# torch.Size([80, 64])
# 154
# torch.Size([96, 64])
# 155
# torch.Size([55, 64])
# 156
# torch.Size([80, 64])
# 157
# torch.Size([72, 64])
# 158
# torch.Size([102, 64])
# 159
# torch.Size([88, 64])
# 160
# torch.Size([82, 64])
# 161
# torch.Size([58, 64])
# 162
# torch.Size([69, 64])
# 163
# torch.Size([82, 64])
# 164
# torch.Size([65, 64])
# 165
# torch.Size([78, 64])
# 166
# torch.Size([112, 64])
# 167
# torch.Size([74, 64])
# 168
# torch.Size([73, 64])
# 169
# torch.Size([81, 64])
# 170
# torch.Size([93, 64])
# 171
# torch.Size([81, 64])
# 172
# torch.Size([71, 64])
# 173
# torch.Size([86, 64])
# 174
# torch.Size([140, 64])
# 175
# torch.Size([110, 64])
# 176
# torch.Size([71, 64])
# 177
# torch.Size([90, 64])
# 178
# torch.Size([59, 64])
# 179
# torch.Size([87, 64])
# 180
# torch.Size([64, 64])
# 181
# torch.Size([85, 64])
# 182
# torch.Size([78, 64])
# 183
# torch.Size([79, 64])
# 184
# torch.Size([92, 64])
# 185
# torch.Size([148, 64])
# 186
# torch.Size([143, 64])
# 187
# torch.Size([86, 64])
# 188
# torch.Size([69, 64])
# 189
# torch.Size([79, 64])
# 190
# torch.Size([70, 64])
# 191
# torch.Size([88, 64])
# 192
# torch.Size([56, 64])
# 193
# torch.Size([66, 64])
# 194
# torch.Size([77, 64])
# 195
# torch.Size([141, 64])
# 196
# torch.Size([108, 64])
# 197
# torch.Size([76, 64])
# 198
# torch.Size([104, 64])
# 199
# torch.Size([61, 64])
# 200
# torch.Size([107, 64])
# 201
# torch.Size([70, 64])
# 202
# torch.Size([75, 64])
# 203
# torch.Size([67, 64])
# 204
# torch.Size([65, 64])
# 205
# torch.Size([84, 64])
# 206
# torch.Size([68, 64])
# 207
# torch.Size([139, 64])
# 208
# torch.Size([74, 64])
# 209
# torch.Size([140, 64])
# 210
# torch.Size([84, 64])
# 211
# torch.Size([91, 64])
# 212
# torch.Size([93, 64])
# 213
# torch.Size([73, 64])
# 214
# torch.Size([74, 64])
# 215
# torch.Size([65, 64])
# 216
# torch.Size([108, 64])
# 217
# torch.Size([72, 64])
# 218
# torch.Size([91, 64])
# 219
# torch.Size([66, 64])
# 220
# torch.Size([86, 64])
# 221
# torch.Size([70, 64])
# 222
# torch.Size([84, 64])
# 223
# torch.Size([95, 64])
# 224
# torch.Size([87, 64])
# 225
# torch.Size([117, 64])
# 226
# torch.Size([94, 64])
# 227
# torch.Size([95, 64])
# 228
# torch.Size([127, 64])
# 229
# torch.Size([86, 64])
# 230
# torch.Size([85, 64])
# 231
# torch.Size([102, 64])
# 232
# torch.Size([59, 64])
# 233
# torch.Size([75, 64])
# 234
# torch.Size([85, 64])
# 235
# torch.Size([59, 64])
# 236
# torch.Size([79, 64])
# 237
# torch.Size([82, 64])
# 238
# torch.Size([108, 64])
# 239
# torch.Size([96, 64])
# 240
# torch.Size([83, 64])
# 241
# torch.Size([73, 64])
# 242
# torch.Size([86, 64])
# 243
# torch.Size([78, 64])
# 244
# torch.Size([68, 64])
# 245
# torch.Size([69, 64])
# 246
# torch.Size([81, 64])
# 247
# torch.Size([76, 64])
# 248
# torch.Size([84, 64])
# 249
# torch.Size([78, 64])
# 250
# torch.Size([90, 64])
# 251
# torch.Size([104, 64])
# 252
# torch.Size([62, 64])
# 253
# torch.Size([79, 64])
# 254
# torch.Size([87, 64])
# 255
# torch.Size([125, 64])
# 256
# torch.Size([80, 64])
# 257
# torch.Size([86, 64])
# 258
# torch.Size([70, 64])
# 259
# torch.Size([75, 64])
# 260
# torch.Size([131, 64])
# 261
# torch.Size([98, 64])
# 262
# torch.Size([72, 64])
# 263
# torch.Size([81, 64])
# 264
# torch.Size([160, 64])
# 265
# torch.Size([89, 64])
# 266
# torch.Size([74, 64])
# 267
# torch.Size([177, 64])
# 268
# torch.Size([68, 64])
# 269
# torch.Size([258, 64])
# 270
# torch.Size([146, 64])
# 271
# torch.Size([78, 64])
# 272
# torch.Size([86, 64])
# 273
# torch.Size([91, 64])
# 274
# torch.Size([59, 64])
# 275
# torch.Size([79, 64])
# 276
# torch.Size([52, 64])
# 277
# torch.Size([66, 64])
# 278
# torch.Size([69, 64])
# 279
# torch.Size([91, 64])
# 280
# torch.Size([153, 64])
# 281
# torch.Size([89, 64])
# 282
# torch.Size([69, 64])
# 283
# torch.Size([60, 64])
# 284
# torch.Size([74, 64])
# 285
# torch.Size([138, 64])
# 286
# torch.Size([79, 64])
# 287
# torch.Size([78, 64])
# 288
# torch.Size([71, 64])
# 289
# torch.Size([77, 64])
# 290
# torch.Size([96, 64])
# 291
# torch.Size([80, 64])
# 292
# torch.Size([90, 64])
# 293
# torch.Size([108, 64])
# 294
# torch.Size([59, 64])
# 295
# torch.Size([76, 64])
# 296
# torch.Size([111, 64])
# 297
# torch.Size([88, 64])
# 298
# torch.Size([68, 64])
# 299
# torch.Size([148, 64])
# 300
# torch.Size([86, 64])
# 301
# torch.Size([116, 64])
# 302
# torch.Size([91, 64])
# 303
# torch.Size([91, 64])
# 304
# torch.Size([108, 64])
# 305
# torch.Size([78, 64])
# 306
# torch.Size([73, 64])
# 307
# torch.Size([90, 64])
# 308
# torch.Size([89, 64])
# 309
# torch.Size([81, 64])
# 310
# torch.Size([79, 64])
# 311
# torch.Size([59, 64])
# 312
# torch.Size([112, 64])
# 313
# torch.Size([117, 64])
# 314
# torch.Size([89, 64])
# 315
# torch.Size([72, 64])
# 316
# torch.Size([93, 64])
# 317
# torch.Size([78, 64])
# 318
# torch.Size([91, 64])
# 319
# torch.Size([83, 64])
# 320
# torch.Size([78, 64])
# 321
# torch.Size([81, 64])
# 322
# torch.Size([71, 64])
# 323
# torch.Size([74, 64])
# 324
# torch.Size([102, 64])
# 325
# torch.Size([85, 64])
# 326
# torch.Size([110, 64])
# 327
# torch.Size([84, 64])
# 328
# torch.Size([72, 64])
# 329
# torch.Size([72, 64])
# 330
# torch.Size([97, 64])
# 331
# torch.Size([66, 64])
# 332
# torch.Size([90, 64])
# 333
# torch.Size([76, 64])
# 334
# torch.Size([71, 64])
# 335
# torch.Size([127, 64])
# 336
# torch.Size([76, 64])
# 337
# torch.Size([99, 64])
# 338
# torch.Size([70, 64])
# 339
# torch.Size([59, 64])
# 340
# torch.Size([83, 64])
# 341
# torch.Size([107, 64])
# 342
# torch.Size([76, 64])
# 343
# torch.Size([111, 64])
# 344
# torch.Size([64, 64])
# 345
# torch.Size([110, 64])
# 346
# torch.Size([66, 64])
# 347
# torch.Size([98, 64])
# 348
# torch.Size([64, 64])
# 349
# torch.Size([81, 64])
# 350
# torch.Size([86, 64])
# 351
# torch.Size([90, 64])
# 352
# torch.Size([95, 64])
# 353
# torch.Size([118, 64])
# 354
# torch.Size([47, 64])
# 355
# torch.Size([82, 64])
# 356
# torch.Size([71, 64])
# 357
# torch.Size([90, 64])
# 358
# torch.Size([113, 64])
# 359
# torch.Size([60, 64])
# 360
# torch.Size([86, 64])
# 361
# torch.Size([79, 64])
# 362
# torch.Size([103, 64])
# 363
# torch.Size([78, 64])
# 364
# torch.Size([449, 64])
# 365
# torch.Size([103, 64])
# 366
# torch.Size([93, 64])
# 367
# torch.Size([102, 64])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-22cdfe29df68> in <cell line: 1>()
#       2   print(f'Epoch [{epoch} / {num_epochs}]')
#       3
# ----> 4   for batch_idx, batch in enumerate(train_iterator):
#       5     print(batch_idx)
#       6     print(batch.eng.shape)
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/iterator.py in __iter__(self)
#     154                     else:
#     155                         minibatch.sort(key=self.sort_key, reverse=True)
# --> 156                 yield Batch(minibatch, self.dataset, self.device)
#     157             if not self.repeat:
#     158                 return
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/batch.py in __init__(self, data, dataset, device)
#      32                 if field is not None:
#      33                     batch = [getattr(x, name) for x in data]
# ---> 34                     setattr(self, name, field.process(batch, device=device))
#      35
#      36     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/field.py in process(self, batch, device)
#     235         """
#     236         padded = self.pad(batch)
# --> 237         tensor = self.numericalize(padded, device=device)
#     238         return tensor
#     239
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/field.py in numericalize(self, arr, device)
#     360
#     361         if self.sequential and not self.batch_first:
# --> 362             var.t_()
#     363         if self.sequential:
#     364             var = var.contiguous()
#
# KeyboardInterrupt:
